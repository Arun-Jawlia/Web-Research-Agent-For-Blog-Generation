# %%
from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage
from datetime import date, datetime, timedelta

# %%
from __future__ import annotations
import operator
from typing import TypedDict, List, Annotated, Literal, Optional

# %%
from dotenv import load_dotenv

# %%
from pathlib import Path
from langchain_community.tools.tavily_search import TavilySearchResults
# Out:
# C:\Users\arunk\AppData\Local\Temp\ipykernel_7128\3339785297.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools.tavily_search import TavilySearchResults

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Task Model

# %% [markdown]
# ## 1. Schemas

# %%
class Task(BaseModel):
    id: int
    title: str
    goal: str = Field(
        ...,
        description='One sentence describing what the reader should be able to do/understand after this section.'
    )
    bullets: List[str] = Field(
        ...,
        min_length = 3,
        max_length = 5,
        description = '3-5 concrete, non-overlapping subpoints ot cover this section.'
    )
    target_words : int = Field(
        ...,
        description = 'Target word count for this section (12-450).'
    )
    tags: List[str] = Field(default_factory=list)
    requires_research:bool = False
    requires_citations: bool = False
    requires_code:bool = False

# %%
class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str
    # New: tells worker what genre this is (Prevents drift)
    blog_kind: Literal['explainer', 'tutorial', 'news_roundup', 'comparison', 'system_design'] = 'explainer'
    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]

# %%
class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at : Optional[str] = None
    snippet: Optional[str] = None
    source: Optional[str] = None

# %%
class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal['closed_book', 'hybrid', 'open_book']
    reason: str
    queries: List[str] = Field(default_factory=list)
    max_results_per_query:int = Field(5, description='How many results to fetch per query (3-8)')

# %%
class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    as_of: str           # ISO date, e.g. "2026-01-29"
    recency_days: int  
    
    sections: Annotated[List[tuple[int, str]], operator.add]
    final: str

# %% [markdown]
# ## 2. LLM

# %%
llm = ChatOpenAI(model = 'gpt-4o')

# %% [markdown]
# ## Router ( Decide Upfront )

# %%
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- For open_book weekly roundup, include queries that reflect the last 7 days constraint.
"""

# %%
def router_node(state: State) -> dict:
    topic = state['topic']
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content = ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}\nAs-of date: {state['as_of']}")
        ]
    )

    # Set default recency window based on mode
    if decision.mode == "open_book":
        recency_days = 7
    elif decision.mode == "hybrid":
        recency_days = 45
    else:
        recency_days = 3650

    return {
        "needs_research": decision.needs_research,
        "mode":decision.mode,
        "queries": decision.queries,
        "recency_days": recency_days
    }

def route_next(state:State)->str:
    return "research" if state['needs_research'] else 'orchestrator'

# %% [markdown]
# ## 4. Research ( Tavily )

# %%
def _tavily_search(query:str, max_results:int = 5) -> List[dict]:
    tool = TavilySearchResults(max_results=max_results)
    results = tool.invoke({'query': query})

    normalized: List[dict] = []
    for r in results or []:
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized

# %%
def _iso_to_date(s: Optional[str]) -> Optional[date]:
    if not s:
        return None
    try:
        return date.fromisoformat(s[:10])
    except Exception:
        return None

# %%
RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- Extract/normalize published_at as ISO (YYYY-MM-DD) if you can infer it from title/snippet.
  If you can't infer a date reliably, set published_at=null (do NOT guess).
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:
    queries = (state.get("queries", []) or [])[:10]
    max_results = 6

    raw_results: List[dict] = []
    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(
                content=(
                    f"As-of date: {state['as_of']}\n"
                    f"Recency days: {state['recency_days']}\n\n"
                    f"Raw results:\n{raw_results}"
                )
            ),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e
    evidence = list(dedup.values())

    # HARD RECENCY FILTER for open_book weekly roundup:
    # keep only items with a parseable ISO date and within the window.
    mode = state.get("mode", "closed_book")
    if mode == "open_book":
        as_of = date.fromisoformat(state["as_of"])
        cutoff = as_of - timedelta(days=int(state["recency_days"]))
        fresh: List[EvidenceItem] = []
        for e in evidence:
            d = _iso_to_date(e.published_at)
            if d and d >= cutoff:
                fresh.append(e)
        evidence = fresh

    return {"evidence": evidence}

# %% [markdown]
# ## 5. Orchestrator (Plan)

# %%
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Flexibility:
- Do NOT use a fixed taxonomy unless it naturally fits.
- You may tag tasks (tags field), but tags are flexible.

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book (weekly news roundup):
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections (no scraping/RSS/how to fetch news) unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient fresh sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)
    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    # Force blog_kind for open_book
    forced_kind = "news_roundup" if mode == "open_book" else None

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n"
                    f"As-of: {state['as_of']} (recency_days={state['recency_days']})\n"
                    f"{'Force blog_kind=news_roundup' if forced_kind else ''}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}\n\n"
                    f"Instruction: If mode=open_book, your plan must NOT drift into a tutorial."
                )
            ),
        ]
    )

    # Ensure open_book forces the kind even if model forgets
    if forced_kind:
        plan.blog_kind = "news_roundup"

    return {"plan": plan}

# %% [markdown]
# ## 6. Fanout

# %%
def fanout(state: State):
    assert state['plan'] is not None
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "as_of": state["as_of"],
                "recency_days": state["recency_days"],                
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %% [markdown]
# ## 7. Workder ( Write one section)

# %%
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard (prevents mid-blog topic drift):
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book (weekly news):
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true (hybrid sections):
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning (concepts, intuition) is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:
    
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")
    as_of = payload.get("as_of")
    recency_days = payload.get("recency_days")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n\n"
                    f"As-of: {as_of} (recency_days={recency_days})\n\n"
                    f"Section title: {task.title}\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [(task.id, section_md)]}

# %% [markdown]
# ## 8. Reducer (merge + save)

# %%
def reducer_node(state: State) -> dict:
    plan = state["plan"]
    if plan is None:
        raise ValueError("Reducer called without a plan.")

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    final_md = f"# {plan.blog_title}\n\n{body}\n"

    filename = f"{plan.blog_title}.md"
    Path(filename).write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %% [markdown]
# ## 9. Build Graph

# %%
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_node)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()
app

# %%
def run(topic: str, as_of: Optional[str] = None):
    if as_of is None:
        as_of = date.today().isoformat()

    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "as_of": as_of,
            "recency_days": 7,   # router may overwrite
            "sections": [],
            "final": "",
        }
    )

    plan: Plan = out["plan"]
    print("\n" + "=" * 100)
    print("TOPIC:", topic)
    print("AS_OF:", out.get("as_of"), "RECENCY_DAYS:", out.get("recency_days"))
    print("MODE:", out.get("mode"))
    print("BLOG_KIND:", plan.blog_kind)
    print("NEEDS_RESEARCH:", out.get("needs_research"))
    print("QUERIES:", (out.get("queries") or [])[:6])
    print("EVIDENCE_COUNT:", len(out.get("evidence", [])))
    if out.get("evidence"):
        print("EVIDENCE_SAMPLE:", [e.model_dump() for e in out["evidence"][:2]])
    print("TASKS:", len(plan.tasks))
    print("SAVED_MD_CHARS:", len(out.get("final", "")))
    print("=" * 100 + "\n")

    return out

# %%
run("Write a blog on Self Attention")
# Out:
# ====================================================================================================
# TOPIC: Write a blog on Self Attention
# AS_OF: 2026-09-14 RECENCY_DAYS: 3650
# MODE: closed_book
# BLOG_KIND: explainer
# NEEDS_RESEARCH: False
# QUERIES: []
# EVIDENCE_COUNT: 0
# TASKS: 6
# SAVED_MD_CHARS: 11234
# ====================================================================================================
# {'topic': 'Write a blog on Self Attention',
#  'mode': 'closed_book',
#  'needs_research': False,
#  'queries': [],
#  'evidence': [],
#  'plan': Plan(blog_title='Decoding Self-Attention: The Backbone of Modern NLP Models', audience='Developers and machine learning practitioners', tone='Informative and Engaging', blog_kind='explainer', constraints=[], tasks=[Task(id=1, title='Introduction to Self-Attention', goal='Understand the basic concept and purpose of self-attention in neural networks.', bullets=['Define self-attention and highlight its role within transformer architectures.', 'Discuss the advantages of self-attention over traditional sequence models like RNNs.', 'Explain the context in which self-attention is typically applied, focusing on NLP tasks.'], target_words=150, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=2, title='Mechanics of Self-Attention', goal='Detail how self-attention operates at a fundamental level, including key components and calculations.', bullets=['Describe the key components: Queries, Keys, and Values (QKV) and their roles.', 'Explain the dot-product calculation and the significance of scaling by the square root of the dimension.', 'Detail how weights are applied to calculate the weighted sum for the attention scores.'], target_words=200, tags=['technical', 'explanation'], requires_research=False, requires_citations=False, requires_code=True), Task(id=3, title='Illustrating Self-Attention with a Code Example', goal='Provide a minimal code illustration to demonstrate self-attention in practice.', bullets=['Write a Python function that simulates the self-attention mechanism using arrays.', 'Display how to calculate attention scores by performing matrix multiplications with Q, K, V.', 'Explain code with comments on step-by-step operations, referencing the mechanics discussed earlier.'], target_words=250, tags=['code', 'example'], requires_research=False, requires_citations=False, requires_code=True), Task(id=4, title='Handling Edge Cases and Performance Considerations', goal='Highlight potential edge cases and performance issues with self-attention mechanisms.', bullets=['Discuss how large input sequences can impact computational efficiency and resource usage.', 'Describe strategies to mitigate performance issues, such as attention masking and sparse attention.', 'Outline potential overflow or numerical stability issues during softmax operations and their solutions.'], target_words=200, tags=['performance', 'edge-cases'], requires_research=False, requires_citations=False, requires_code=False), Task(id=5, title='Self-Attention in Transformer Models', goal='Connect the concept of self-attention to its practical use in transformer models.', bullets=['Briefly introduce transformer architecture and its reliance on self-attention.', 'Discuss how self-attention enables parallelization, benefiting large-scale model training.', 'Highlight the impact of self-attention on the success of models like BERT and GPT.'], target_words=200, tags=['transformer', 'practical'], requires_research=False, requires_citations=False, requires_code=False), Task(id=6, title='Future Directions and Innovations in Self-Attention', goal='Explore potential future developments and innovations in self-attention.', bullets=["Speculate on how evolving hardware may influence self-attention's efficiency.", 'Discuss ongoing research trends that aim to optimize self-attention for diverse applications.', 'Reflect on the growing integration of self-attention in multimodal and cross-domain tasks.'], target_words=150, tags=['future', 'trends'], requires_research=False, requires_citations=False, requires_code=False)]),
#  'as_of': '2026-09-14',
#  'recency_days': 3650,
#  'sections': [(1,
#    '## Introduction to Self-Attention\n\nSelf-attention is a mechanism used in neural networks to assign varying levels of importance to different words or tokens in an input sequence. It is a core component of transformer architectures, where it efficiently models relationships between all parts of the input data regardless of their positions. By calculating pairwise interactions between tokens, self-attention allows transformers to capture complex dependencies and contextual cues beyond local neighborhoods.\n\nCompared to traditional sequence models like Recurrent Neural Networks (RNNs), self-attention provides significant advantages. One key improvement is parallelizability. Unlike RNNs, which process sequences token-by-token, self-attention can process tokens simultaneously, leading to faster computation and better scalability with large datasets. This characteristic makes it particularly effective for tasks with long-range dependencies.\n\nSelf-attention is commonly applied in Natural Language Processing (NLP) tasks such as language translation, summarization, and question-answering. In these tasks, capturing the context and meaning that may span the entire sentence or document is crucial. Self-attention excels by enabling models to focus on relevant parts of the input, ensuring that each word is evaluated in light of the entire context.'),
#   (2,
#    "## Mechanics of Self-Attention\n\nThe self-attention mechanism is integral to the architecture of many modern NLP models, helping them understand context and focus on relevant parts of the input data. At its core, self-attention relies on three key components: Queries, Keys, and Values - often referred to as QKV.\n\n1. **Queries, Keys, and Values (QKV):** Each input token is transformed into three distinct vectors: the Query, Key, and Value. These vectors allow the model to compute the attention score, which determines how much focus one word should receive relative to other words in a sequence. Queries and Keys are used to calculate attention weights, while Values are used to generate the final output by weighing these Values. \n\n2. **Dot-Product Calculation and Scaling:** To compute the attention scores, the Query vectors are compared against the Key vectors using a dot product. This operation essentially measures the similarity between the two sets of vectors. To ensure numerical stability and more effective learning, the result is scaled by the square root of the dimension of the Key vectors. This scaling prevents the softmax function, which converts scores into probabilities, from saturating when the dimension of Keys is large.\n\n    ```python\n    import numpy as np\n\n    def scaled_dot_product_attention(Q, K, V, d_k):\n        # Calculate the dot products of the Queries (Q) with the Keys (K), scale by sqrt(d_k)\n        scores = np.dot(Q, K.T) / np.sqrt(d_k)\n        # Apply softmax to get attention weights\n        attention_weights = softmax(scores, axis=-1)\n        # Multiply the attention weights with the Values (V)\n        output = np.dot(attention_weights, V)\n        return output\n\n    def softmax(x, axis):\n        e_x = np.exp(x - np.max(x, axis=axis, keepdims=True))\n        return e_x / np.sum(e_x, axis=axis, keepdims=True)\n    ```\n\n3. **Calculating Weighted Sum for Attention Scores:** The attention weights obtained from the softmax of the scaled dot products are then used to perform a weighted sum of the Value vectors. This results in a new sequence of vectors that encode the information from the original sequence, focusing on key parts of the input data as determined by the attention scores. The self-attention mechanism, thus, dynamically adjusts the weights based on the context provided by the input sequence.\n\nIn summary, self-attention effectively combines these QKV vectors to direct the model's attention to the most relevant parts of the input, making it a powerful technique for capturing nuances and relationships within the data."),
#   (3,
#    '## Illustrating Self-Attention with a Code Example\n\nTo understand how self-attention works in practice, let\'s explore a minimal Python implementation. Self-attention is essential for encoding relationships within input sequences, typically involving three matrices: Query (Q), Key (K), and Value (V).\n\nHere\'s a simple Python function demonstrating the self-attention mechanism:\n\n```python\nimport numpy as np\n\ndef self_attention(Q, K, V):\n    """\n    Simulates self-attention mechanism.\n    \n    :param Q: Query matrix\n    :param K: Key matrix\n    :param V: Value matrix\n    :return: Attention output\n    """\n    # Step 1: Calculate the raw attention scores using matrix multiplication of Q and K transposed.\n    scores = np.matmul(Q, K.T)\n    \n    # Step 2: Scale the scores by the square root of the depth of the matrix K.\n    depth = K.shape[-1]\n    scaled_scores = scores / np.sqrt(depth)\n    \n    # Step 3: Apply softmax to get the weights (normalized attention scores).\n    attention_weights = np.exp(scaled_scores) / np.sum(np.exp(scaled_scores), axis=1, keepdims=True)\n    \n    # Step 4: Multiply weights with the Value matrix to get the final output.\n    attention_output = np.matmul(attention_weights, V)\n    \n    return attention_output\n\n# Example matrices\nQ = np.array([[1, 0, 1], [0, 1, 0]])\nK = np.array([[0, 1, 0], [1, 0, 1]])\nV = np.array([[1, 2], [3, 2]])\n\noutput = self_attention(Q, K, V)\nprint("Self-Attention Output:\\n", output)\n```\n\n### Code Explanation\n\n1. **Raw Attention Scores**: We calculate the attention scores by performing matrix multiplication between Q and the transpose of K. This captures the similarity between the query and the keys.\n\n2. **Scaling**: The scores are scaled down by the square root of the depth of K (number of columns) to stabilize the gradient during training.\n\n3. **Softmax Application**: We then apply the softmax function to normalize the scores into a probability distribution. This generates weights indicating the importance of each value element in the context.\n\n4. **Output Calculation**: Finally, the attention weights are used to compute a weighted sum of the values in V, resulting in the attention output.\n\nThis code chunk encapsulates a fundamental component of the transformer architecture, providing a clear demonstration of how self-attention distributes focus across an input sequence.'),
#   (4,
#    '## Handling Edge Cases and Performance Considerations\n\nSelf-attention mechanisms are pivotal in handling large input sequences, but they come with computational challenges. When dealing with extensive sequences, the computational cost and resource usage of models leveraging self-attention can grow quadratically, leading to efficiency bottlenecks and prohibitive memory consumption in traditional transformer architectures.\n\nTo mitigate these performance issues, several strategies have been developed. Attention masking is used to disregard irrelevant parts of the input sequence during computation, thereby reducing unnecessary complexity. Sparse attention mechanisms further optimize resource usage by focusing the attention computations on only a subset of the relevant tokens, rather than the entire sequence. This can significantly reduce the computational load and improve throughput when execution resources are limited.\n\nAnother critical consideration in implementing self-attention is the potential for overflow or numerical instability during the execution of softmax operations. This issue arises primarily because the exponentiation step in softmax can lead to very large numbers, causing overflow. A common solution to this problem is to apply a normalization technique that involves subtracting the maximum value from each set of scores prior to applying softmax. This not only helps in mitigating overflow risks but also improves the numerical stability of the computations.\n\nIn summary, by leveraging techniques such as attention masking and sparse attention, and addressing numerical stability in softmax operations, one can significantly enhance the efficiency and reliability of self-attention mechanisms even when handling large input sequences.'),
#   (5,
#    '## Self-Attention in Transformer Models\n\nThe transformer architecture marks a pivotal change in natural language processing by leveraging self-attention mechanisms. Transformers are fundamentally composed of layers of self-attention and feed-forward networks, facilitating efficient processing of input data. Unlike previous models that processed sequences sequentially, transformers use self-attention to calculate the relevance of one part of the input data sequence in relation to another, concurrently across all positions.\n\nSelf-attention significantly enhances parallelization capabilities, crucial for training large-scale models. By allowing the model to focus simultaneously on different parts of the input sequence, this approach circumvents the limitations of sequential processing inherent in RNNs and LSTMs. Consequently, transformers can leverage modern hardware acceleration more effectively, training vast datasets across multiple GPUs with reduced computation time.\n\nThe implementation of self-attention has been instrumental in the revolutionary success of models such as BERT and GPT. These models have achieved superior performance on a range of natural language tasks, attributing their prowess to the ability of self-attention to capture intricate dependencies within the text. By understanding and modeling context at various levels, BERT and GPT have set new benchmarks in tasks like question answering, translation, and text generation, broadening the potential applications and impact of transformers in the AI industry.'),
#   (6,
#    "## Future Directions and Innovations in Self-Attention\n\nAs the demand for more efficient NLP models continues to grow, evolving hardware plays a crucial role in enhancing the efficiency of self-attention mechanisms. With the advancement of specialized devices like GPUs and TPUs, we can anticipate significant improvements in the processing power and speed of self-attention operations. These hardware enhancements are likely to accelerate computations, reduce energy consumption, and enable real-time processing, thereby broadening the scope of self-attention applications.\n\nOngoing research is heavily focused on optimizing self-attention for a wide range of applications. This includes efforts to reduce the computational complexity associated with self-attention. Techniques like sparse attention and low-rank factorization are being explored to maintain performance while lowering resource usage. Such optimizations are crucial for deploying self-attention in edge devices and mobile platforms where computational resources are limited.\n\nIn addition, the integration of self-attention in multimodal and cross-domain tasks is increasingly prevalent. By combining different types of data—such as text, image, and audio—self-attention models are being adapted to handle new challenges in fields like robotics, video processing, and conversational AI. This integration not only enhances the models' capabilities but also paves the way for innovative applications that leverage diverse data inputs to deliver more sophisticated and context-aware solutions.")],
#  'final': '# Decoding Self-Attention: The Backbone of Modern NLP Models\n\n## Introduction to Self-Attention\n\nSelf-attention is a mechanism used in neural networks to assign varying levels of importance to different words or tokens in an input sequence. It is a core component of transformer architectures, where it efficiently models relationships between all parts of the input data regardless of their positions. By calculating pairwise interactions between tokens, self-attention allows transformers to capture complex dependencies and contextual cues beyond local neighborhoods.\n\nCompared to traditional sequence models like Recurrent Neural Networks (RNNs), self-attention provides significant advantages. One key improvement is parallelizability. Unlike RNNs, which process sequences token-by-token, self-attention can process tokens simultaneously, leading to faster computation and better scalability with large datasets. This characteristic makes it particularly effective for tasks with long-range dependencies.\n\nSelf-attention is commonly applied in Natural Language Processing (NLP) tasks such as language translation, summarization, and question-answering. In these tasks, capturing the context and meaning that may span the entire sentence or document is crucial. Self-attention excels by enabling models to focus on relevant parts of the input, ensuring that each word is evaluated in light of the entire context.\n\n## Mechanics of Self-Attention\n\nThe self-attention mechanism is integral to the architecture of many modern NLP models, helping them understand context and focus on relevant parts of the input data. At its core, self-attention relies on three key components: Queries, Keys, and Values - often referred to as QKV.\n\n1. **Queries, Keys, and Values (QKV):** Each input token is transformed into three distinct vectors: the Query, Key, and Value. These vectors allow the model to compute the attention score, which determines how much focus one word should receive relative to other words in a sequence. Queries and Keys are used to calculate attention weights, while Values are used to generate the final output by weighing these Values. \n\n2. **Dot-Product Calculation and Scaling:** To compute the attention scores, the Query vectors are compared against the Key vectors using a dot product. This operation essentially measures the similarity between the two sets of vectors. To ensure numerical stability and more effective learning, the result is scaled by the square root of the dimension of the Key vectors. This scaling prevents the softmax function, which converts scores into probabilities, from saturating when the dimension of Keys is large.\n\n    ```python\n    import numpy as np\n\n    def scaled_dot_product_attention(Q, K, V, d_k):\n        # Calculate the dot products of the Queries (Q) with the Keys (K), scale by sqrt(d_k)\n        scores = np.dot(Q, K.T) / np.sqrt(d_k)\n        # Apply softmax to get attention weights\n        attention_weights = softmax(scores, axis=-1)\n        # Multiply the attention weights with the Values (V)\n        output = np.dot(attention_weights, V)\n        return output\n\n    def softmax(x, axis):\n        e_x = np.exp(x - np.max(x, axis=axis, keepdims=True))\n        return e_x / np.sum(e_x, axis=axis, keepdims=True)\n    ```\n\n3. **Calculating Weighted Sum for Attention Scores:** The attention weights obtained from the softmax of the scaled dot products are then used to perform a weighted sum of the Value vectors. This results in a new sequence of vectors that encode the information from the original sequence, focusing on key parts of the input data as determined by the attention scores. The self-attention mechanism, thus, dynamically adjusts the weights based on the context provided by the input sequence.\n\nIn summary, self-attention effectively combines these QKV vectors to direct the model\'s attention to the most relevant parts of the input, making it a powerful technique for c ...
